# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
df_eda = pd.read_csv(
    r"C:\Users\M.Durga Prasad\OneDrive\Desktop\Customer_Churn_Prediction\data\processed\customer_churn_cleaned.csv"
)

# %%
df_eda.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df_eda.shape
# Out:
# (7043, 21)

# %%
df_eda.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df_eda['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df_eda['Churn'].value_counts(normalize=True) * 100
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
df_eda['Churn'].value_counts().plot(kind = 'bar')

plt.title('Customer Churn Distribution')
plt.xlabel('Churn')
plt.ylabel('Number of Customers')
plt.show()

# %%
Churn_percentage = df_eda['Churn'].value_counts(normalize=True) * 100

Churn_percentage.plot(kind = 'bar')
plt.title('Customer Churn Percentage')
plt.xlabel('Churn')
plt.

# %%
df_eda['tenure'].describe
# Out:
# count    7043.000000
# mean       32.371149
# std        24.559481
# min         0.000000
# 25%         9.000000
# 50%        29.000000
# 75%        55.000000
# max        72.000000
# Name: tenure, dtype: float64

# %%
plt.figure(figsize=(8,6))

plt.hist(df_eda['tenure'], bin = 50)
plt.title('Distribution of Te')
plt.xlabel('Tenure (month)')
plt.ylabel('Number of customers')

# %%
df_eda['MonthlyCharges'].describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: MonthlyCharges, dtype: float64

# %%
plt.figure(figsize=(8,6))
plt.hist(df_eda['MonthlyCharges'], bins = 30)
plt.title('Distribution of Monthly Charges')
plt.xlabel('Monthly Charges')
plt.ylabel('Number of customer')
plt.show

# %%
df_eda['TotalCharges'].describe()
# Out:
# count    7043.000000
# mean     2279.734304
# std      2266.794470
# min         0.000000
# 25%       398.550000
# 50%      1394.550000
# 75%      3786.600000
# max      8684.800000
# Name: TotalCharges, dtype: float64

# %%
plt.figure(figsize=(8,6))
plt.hist(df_eda['TotalCharges'], bins = 30)
plt.title('Distribution Of Total Charges')
plt.xlebal('Total Charges')
plt.ylabel('Number of customer')
plt.show()

# %%
pd.crosstab(df_eda['Contract'], df_eda['Churn'], normalize = 'index') * 100
# Out:
# Churn                  No        Yes
# Contract
# Month-to-month  57.290323  42.709677
# One year        88.730482  11.269518
# Two year        97.168142   2.831858

# %%
contract_churn = pd.crosstab(df_eda['Contract'], df_eda['Churn'], normalize='index') * 100
contract_churn.plot(kind='bar', figsize=(8,5))
plt.title('Contract VS Churn')
plt.xlabel('Contract type')
plt.ylabel('Percentage')
plt.xticks(rotation=0)
plt.legend()
plt.show()

# %%
df_eda['InternetService'].describe()
# Out:
# count            7043
# unique              3
# top       Fiber optic
# freq             3096
# Name: InternetService, dtype: object

# %%
intservice_Churn = pd.crosstab(df_eda['InternetService'], df_eda['Churn'], normalize = 'index') * 100

intservice_Churn.plot(kind = 'bar', figsize=(8,6))
plt.title('Internet Service VS Churn')
plt.xlabel('Service Types')
plt.ylabel('Percentage')
plt.xticks(rotation=0)
plt.legend()
plt.show()

# %%
df_eda['PaymentMethod'].describe()
# Out:
# count                 7043
# unique                   4
# top       Electronic check
# freq                  2365
# Name: PaymentMethod, dtype: object

# %%
payment_churn = pd.crosstab(df_eda['PaymentMethod'], df_eda['Churn'], normalize='index') * 100

payment_churn.plot(kind = 'bar', figsize=(9,6))
plt.title('Payment Methods VS Churn')
plt.xlabel('Payment Methods')
plt.ylabel('Percentage')
plt.xticks(rotation=0)
plt.legend()
plt.show()

# %%
df_eda['SeniorCitizen'].describe()
# Out:
# count    7043.000000
# mean        0.162147
# std         0.368612
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: SeniorCitizen, dtype: float64

# %%
senior_churn = pd.crosstab(df_eda['SeniorCitizen'], df_eda['Churn'], normalize='index') * 100
senior_churn.plot(kind = 'bar', figsize=(7,5))
plt.title('Senior Citizens VS Churn')
plt.xlabel('Senior Citizen (yes = 1, no = 0)')
plt.ylabel('Percentage %')
plt.xticks(rotation=0)
plt.legend()
plt.show()

# %%
df_eda['Partner'].describe()
# Out:
# count     7043
# unique       2
# top         No
# freq      3641
# Name: Partner, dtype: object

# %%
partner_churn
# Out:
# Churn           No        Yes
# Partner
# No       67.042021  32.957979
# Yes      80.335097  19.664903

# %%
partner_churn = pd.crosstab(df_eda['Partner'], df_eda['Churn'], normalize = 'index') * 100

partner_churn.plot(kind = 'bar', figsize=(7,5))
plt.title('Partner VS Churn')
plt.xlabel('Partner (No , Yes)')
plt.ylabel('Percentage')
plt.xticks(rotation=0)
plt.legend()
plt.show()

# %%
df_eda['Dependents'].describe()
# Out:
# count     7043
# unique       2
# top         No
# freq      4933
# Name: Dependents, dtype: object

# %%
Dependents_churn = pd.crosstab(df_eda['Dependents'], df_eda['Churn'], normalize='index') * 100
Dependents_churn.plot(kind='bar', figsize=(7,5))
plt.title('Dependents VS Churn')
plt.xlabel('Dependents (NO , YES)')
plt.ylabel('Percentage')
plt.xticks(rotation=0)
plt.legend()
plt.show()

# %%
df_eda['OnlineSecurity'].describe()
# Out:
# count     7043
# unique       3
# top         No
# freq      3498
# Name: OnlineSecurity, dtype: object

# %%
OnlineSecurity_churn = pd.crosstab(df_eda['OnlineSecurity'], df_eda['Churn'], normalize='index') * 100
OnlineSecurity_churn.plot(kind='bar', figsize=(7,5))
plt.title('Online Security VS Churn')
plt.xlabel('Online Security ( NO , YES , NO Service)')
plt.ylabel('Percentage')
plt.xticks(rotation=0)
plt.legend()
plt.show()

# %%
df_eda['TechSupport'].describe()
# Out:
# count     7043
# unique       3
# top         No
# freq      3473
# Name: TechSupport, dtype: object

# %%
techsup_churn = pd.crosstab(df_eda['TechSupport'], df_eda['Churn'], normalize='index') * 100
techsup_churn.plot(kind='bar', figsize=(7,5))
plt.title('Tech Support VS Churn')
plt.xlabel('Tech Support')
plt.ylabel('Percentage')
plt.xticks(rotation=0)
plt.legend()
plt.show()

# %%
df_eda['StreamingTV'].describe()
# Out:
# count     7043
# unique       3
# top         No
# freq      2810
# Name: StreamingTV, dtype: object

# %%
streamingTV_churn = pd.crosstab(df_eda['StreamingTV'], df_eda['Churn'], normalize = 'index') * 100
streamingTV_churn.plot(kind='bar', figsize=(7,5))
plt.title('Streaming TV VS Churn')
plt.xlabel('Streaming TV')
plt.ylabel('Percentage')
plt.xticks(rotation=0)
plt.legend()
plt.show()

# %%
df_eda['StreamingMovies'].describe()
# Out:
# count     7043
# unique       3
# top         No
# freq      2785
# Name: StreamingMovies, dtype: object

# %%
streamingMovies_churn = pd.crosstab(df_eda['StreamingMovies'], df_eda['Churn'], normalize = 'index') * 100
streamingTV_churn.plot(kind='bar', figsize=(7,5))
plt.title('Streaming Movies VS Churn')
plt.xlabel('Streaming ')
plt.ylabel('Percentage')
plt.xticks(rotation=0)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
df_eda.boxplot( column='tenure', by='Churn')
plt.title('Tenure VS Churn')
plt.suptitle('')
plt.xlabel('Churn')
plt.ylabel('Tenure (months)')
plt.show()

# %%
plt.figure(figsize=(8,6))
df_eda.boxplot(column='MonthlyCharges', by='Churn')
plt.title('Monthly Charges VS Churn')
plt.suptitle('')
plt.xlabel('Churn')
plt.ylabel('Monthly Charges')
plt.show()

# %%
plt.figure(figsize=(8,6))
df_eda.boxplot(column='TotalCharges', by='Churn')
plt.title('Total Charges VS Churn')
plt.suptitle('')
plt.xlabel('Churn')
plt.ylabel('Total Charges')
plt.show()

# %%
df_eda.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
df_eda['Churn_encoded'] = df_eda['Churn'].map({'No':0, 'Yes':1})

# %%
df_eda[['Churn_encoded', 'Churn']].head()
# Out:
#    Churn_encoded Churn
# 0              0    No
# 1              0    No
# 2              1   Yes
# 3              0    No
# 4              1   Yes

# %%
corr = df_eda[['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges', 'Churn_encoded']].corr()
corr
# Out:
#                 SeniorCitizen    tenure  MonthlyCharges  TotalCharges  \
# SeniorCitizen        1.000000  0.016567        0.220173      0.103006
# tenure               0.016567  1.000000        0.247900      0.826178
# MonthlyCharges       0.220173  0.247900        1.000000      0.651174
# TotalCharges         0.103006  0.826178        0.651174      1.000000
# Churn_encoded        0.150889 -0.352229        0.193356     -0.198324
#
#                 Churn_encoded
# SeniorCitizen        0.150889
# tenure              -0.352229
# MonthlyCharges       0.193356
# TotalCharges        -0.198324
# Churn_encoded        1.000000

# %%
plt.figure(figsize=(8,6))

sns.heatmap(corr, annot = True, cmap = 'coolwarm', fmt = '.2f')
plt.title('Correlation')
plt.xticks(rotation=0)
plt.show()
